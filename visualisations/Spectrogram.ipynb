# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from spectrogram_plot import spectrogram_plot

# %%
#importing data for march
mar  = (pd.read_feather(r'C:\monthly_data' + '\\2019_03' + '.feather'))
df = mar[(mar['timestamp'] > pd.to_datetime('2019-03-15 09:00:13.944')) & (mar['timestamp'] < pd.to_datetime('2019-03-15 10:00:13.944'))]
spectrogram_plot(df)

# %%
#importing data for march - zoom in on loud crack 
mar  = (pd.read_feather(r'C:\monthly_data' + '\\2019_03' + '.feather'))
df = mar[(mar['timestamp'] > pd.to_datetime('2019-03-15 09:16:13.944')) & (mar['timestamp'] < pd.to_datetime('2019-03-15 09:18:13.944'))]
spectrogram_plot(df)

# %%
#importing data for may 
may  = (pd.read_feather(r'C:\monthly_data' + '\\2019_05' + '.feather'))
df = may[(may['timestamp'] > pd.to_datetime('2019-05-15 15:00:13.944')) & (may['timestamp'] < pd.to_datetime('2019-05-15 16:00:13.944'))]
spectrogram_plot(df)
